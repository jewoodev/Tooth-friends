# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14311, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 14311 (delta 31), reused 30 (delta 10), pack-reused 14242
# Receiving objects: 100% (14311/14311), 13.59 MiB | 17.60 MiB/s, done.
# Resolving deltas: 100% (9838/9838), done.
# /content/yolov5
#      |████████████████████████████████| 182 kB 35.4 MB/s
#      |████████████████████████████████| 62 kB 1.3 MB/s
#      |████████████████████████████████| 1.6 MB 50.3 MB/s

# %%
# !unzip ../dataset.zip
# Out:
# Archive:  ../dataset.zip
#    creating: content/dataset/test/
#    creating: content/dataset/test/train/
#    creating: content/dataset/test/train/labels/
#   inflating: content/dataset/test/train/labels/┼й╢є┐ю (88).txt
#   inflating: content/dataset/test/train/labels/╖╣┴° (143).txt
#   inflating: content/dataset/test/train/labels/╖╣┴° (238).txt
#   inflating: content/dataset/test/train/labels/2┬ў (77).txt
#  extracting: content/dataset/test/train/labels/─б░ц║╬┐ь╜─ (132).txt
#   inflating: content/dataset/test/train/labels/└╠╗ч└╠ (65).txt
#   inflating: content/dataset/test/train/labels/166.txt
#   inflating: content/dataset/test/train/labels/2┬ў (49).txt
#   inflating: content/dataset/test/train/labels/2┬ў (39).txt
#   inflating: content/dataset/test/train/labels/─б░ц║╬┐ь╜─ (51).txt
#   inflating: content/dataset/test/train/labels/└╬╖╣└╠┐┬╖╣└╠ (63).txt
#   inflating: content/dataset/test/train/labels/─б░ц║╬╕╢╕Ё (21).txt
#   inflating: content/dataset/test/train/labels/215.txt
# ...

# %%
# !python train.py --data "data/dataset.yaml" --epochs 300
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-24-gf8539a6 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python val.py --data "data/dataset.yaml" --weights "/content/yolov5/runs/train/exp/weights/best.pt"

# %%
# !python detect.py --weights "/content/yolov5/runs/train/exp/weights/best.pt" --source "/content/yolov5/dataset/test/images"

# %%
# !zip -r yolov5epochs300.zip /content/yolov5
# Out:
#   adding: content/yolov5/ (stored 0%)
#   adding: content/yolov5/detect.py (deflated 69%)
#   adding: content/yolov5/utils/ (stored 0%)
#   adding: content/yolov5/utils/__init__.py (deflated 54%)
#   adding: content/yolov5/utils/dataloaders.py (deflated 71%)
#   adding: content/yolov5/utils/metrics.py (deflated 66%)
#   adding: content/yolov5/utils/triton.py (deflated 67%)
#   adding: content/yolov5/utils/general.py (deflated 66%)
#   adding: content/yolov5/utils/docker/ (stored 0%)
#   adding: content/yolov5/utils/docker/Dockerfile-cpu (deflated 52%)
#   adding: content/yolov5/utils/docker/Dockerfile-arm64 (deflated 52%)
#   adding: content/yolov5/utils/docker/Dockerfile (deflated 55%)
#   adding: content/yolov5/utils/autoanchor.py (deflated 60%)
#   adding: content/yolov5/utils/flask_rest_api/ (stored 0%)
#   adding: content/yolov5/utils/flask_rest_api/restapi.py (deflated 48%)
#   adding: content/yolov5/utils/flask_rest_api/README.md (deflated 52%)
# ...

# %%
# !zip -r dataset.zip /content/yolov5/dataset
